# %%
import torch
from torch import nn
import matplotlib.pyplot as plt
import numpy as np

# %%
#can use linspace
length = 10000 #how many points for each sine wave #each of the 100 samples has 1000 points
width = 20

#X = np.empty((n_samples, lenght), dtype=np.float32)
#y = np.sin(X/1.0/width).astype(np.float32)

X = torch.linspace(-10, 10, steps=length)

y = torch.sin(X*5)

print(X)
# Out:
# tensor([-10.0000,  -9.9980,  -9.9960,  ...,   9.9960,   9.9980,  10.0000])

# %%
plt.figure(figsize=(40, 32))
plt.scatter(X, y)
plt.show()
